# %%
# Cell 1: Install dependencies
# !pip install mlxtend
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Cell 2: Mount Google Drive (if storing data there)
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cell 3: Upload or clone this script
# from google.colab import files
# files.upload()  # select task3_integration.py
# or
# !git clone <your-repo-url>
# Out:
#      <input type="file" id="files-5770551e-1b20-42a3-b79b-556515516918" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5770551e-1b20-42a3-b79b-556515516918">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Cell 4: Import and load models
import pandas as pd
import task3_integration as tri
train_df = pd.read_csv('Groceries data train.csv')
test_df  = pd.read_csv('Groceries data test.csv')
cf_model, hybrid_model, train_dataset = tri.main(
    'Groceries data train.csv',
    'Groceries data test.csv'
)
# Out:
# Notebook context; returning models.

# %%
uid='U1001'; hist=train_df[train_df['User_id']==uid]['itemDescription'].tolist()
pats=tri.get_frequent_patterns(uid,train_df)
print('CF-only:', cf_model.recommend(uid,exclude_items=hist))
print('Hybrid :', hybrid_model.recommend(uid,patterns_df=pats,exclude=hist))
# Out:
# CF-only: []
# Hybrid : []

# %%
pats
# Out:
# Empty DataFrame
# Columns: [itemsets, support]
# Index: []

# %%
import task3_integration as tri
# 1) Load your data and get back the models & train DataFrame
cf_model, hybrid_model, train_df = tri.main(
    'Groceries data train.csv',
    'Groceries data test.csv'
)

# 2) Pick a user you know exists in train_df
user = train_df['User_id'].iloc[0]

# 3) Try mining their patterns
patterns = tri.get_frequent_patterns(user, train_df)
print("Frequent patterns (top 5):")
print(patterns.head())

# 4) Test CF‑only recommendations
hist = train_df[train_df['User_id']==user]['itemDescription'].tolist()
recs_cf = cf_model.recommend(user, exclude_items=hist)
print("CF‑only recs:", recs_cf)

# 5) Test Hybrid recommendations
recs_h = hybrid_model.recommend(user, patterns_df=patterns, exclude=hist)
print("Hybrid recs:", recs_h)
# Out:
# Notebook context; returning models.
# Frequent patterns (top 5):
#    support                  itemsets
# 0      0.5           (shopping bags)
# 1      0.5                 (cleaner)
# 2      0.5          (instant coffee)
# 3      0.5           (domestic eggs)
# 4      0.5  (shopping bags, cleaner)
# CF‑only recs: ['whole milk', 'rolls/buns', 'other vegetables', 'root vegetables', 'newspapers']
# Hybrid recs: ['whole milk', 'rolls/buns', 'other vegetables', 'root vegetables', 'newspapers']
